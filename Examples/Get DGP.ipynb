# %% [markdown]
# # Testing a Data Generating Process Class

# %% [markdown]
# ### import

# %%
# insert code here
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import seaborn as sns
import importlib
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import pandas as pd
from hmmlearn import hmm
from arch import arch_model
import DGP

# %% [markdown]
# # Testing with constants.

# %%
importlib.reload(DGP)
from DGP import DataGeneratingProcess as dgp
params = {
    'dist': 'normal',
    'nu': [10, 15, 25, 65, 100],
    'omega': [0.01, 0.03, 0.02, 0.01, 0.01],
    'alpha': [0.5, 0.2, 0, 0, 0],
    'beta': [0, 0, 0, 0, 0],
    'mu': [-0.3, 0.3, 0, 0.5, -0.5],
    'phi': [0.3, 0.7, -0, 0, -0],
    'phi_2': [0,-0, -0, 0,-0],
    'phi_3': [-0, 0,-0,0,-0]
}
dat = dgp(process_type=params,n_states = 3)
dat.generate()

# print(generated_data)
# print(generated_data.describe())
# # Access attributes of the instance
# print("Transition Matrix:\n", dgp_instance.transition_matrix)
# print("Mean:", dgp_instance.mean)
# print("Variance:", dgp_instance.variance)
# Out:
# [[0.99236433 0.0046842  0.00674462]
#  [0.00763567 0.9953158  0.00674462]
#  [0.         0.         0.98651075]]
#      State         X     Noise     Sigma
# 0        0  0.000000  0.000000  0.000000
# 1        0 -0.381520 -0.815202  0.100000
# 2        0 -0.901530 -1.692916  0.287713
# 3        0 -0.585088 -0.022671  0.645274
# 4        0 -0.657895 -0.428463  0.425634
# ..     ...       ...       ...       ...
# 995      0 -0.257808  0.257964  0.105956
# 996      1  0.266028  0.704058  0.208070
# 997      1  0.137201 -1.660974  0.210129
# 998      1  0.668177  1.480997  0.183752
# 999      1  0.822351  0.158163  0.345387
#
# [1000 rows x 4 columns]
#              State            X        Noise        Sigma
# count  1000.000000  1000.000000  1000.000000  1000.000000
# mean      0.498000     0.240744     0.018249     0.400601
# std       0.500246     0.837264     0.979353     0.248790
# min       0.000000    -2.862003    -3.026519     0.000000
# 25%       0.000000    -0.381804    -0.642081     0.229554
# 50%       0.000000     0.115863     0.043616     0.344895
# 75%       1.000000     0.810186     0.665738     0.509816
# max       1.000000     3.649715     3.013708     2.026211
