# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('asd.csv')
df
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                         Formue efter population, alder, enhed, tid, omraade og formuetype
#                                                                                                            Nettoformue I alt (2020-definition A+B+CX-D-E-F) Aktiver I alt (2020-definition A+B+CX) A.1. Helaarsbolig, Ejerboliger A.5. Biler B. Finansiel formue i alt (2020-defintion) B.1. Indestaaende i pengeinstitutter B.2. Obligationer B.3. Aktier i depot (oftest noterede) mv. B.4. Andel i investeringsfonde         B.7. indestaaende paa virksomhedsordningen
# ...
