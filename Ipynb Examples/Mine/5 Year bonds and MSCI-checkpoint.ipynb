# %%
import yfinance as yf
import pandas as pd

# Tickers
tickers = ['SWDA.L', 'DBXG', 'IBCL']

# Dates
start_date = '2020-11-15'
end_date = '2023-11-15'

# Function to get closing prices
def get_closing_prices(tickers, start_date, end_date):
    closing_prices = pd.DataFrame()
    for ticker in tickers:
        data = yf.download(ticker, start=start_date, end=end_date)
        closing_prices[ticker] = data['Close']
    return closing_prices

# Fetch and display data
closing_data = get_closing_prices(tickers, start_date, end_date)
print(closing_data)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['DBXG']: Exception('%ticker%: No timezone found, symbol may be delisted')
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['IBCL']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2020-11-15 -> 2023-11-15)')
#             SWDA.L  DBXG  IBCL
# Date
# 2020-11-16  5281.0   NaN   NaN
# 2020-11-17  5251.5   NaN   NaN
# 2020-11-18  5249.0   NaN   NaN
# 2020-11-19  5220.5   NaN   NaN
# 2020-11-20  5221.0   NaN   NaN
# ...            ...   ...   ...
# 2023-11-08  6700.0   NaN   NaN
# 2023-11-09  6745.0   NaN   NaN
# 2023-11-10  6745.0   NaN   NaN
# 2023-11-13  6774.0   NaN   NaN
# 2023-11-14  6802.0   NaN   NaN
#
# [748 rows x 3 columns]

# %%
import yfinance as yf
import seaborn as sns
import matplotlib.pyplot as plt
from datetime import datetime, timedelta

# Set the end date to today and start date to 5 years ago
end_date = '2023-11-16'
start_date = '2020-11-17'
# Define the symbols
symbols = ['SWDA.L', ]#'EM1015.L', 'DBXG.L']  # Adjust the symbols if needed

# Download the data for each symbol
data['SWDA.L'] = yf.download('SWDA.L', start=start_date, end=end_date)
sns.lineplot(data=data[symbol]['Close'])
data['EM1015.L'] = yf.download('EM1015.L', start=start_date, end=end_date)
sns.lineplot(data=data['EM1015.L']['Close'])
data['DBXG.L'] = yf.download('DBXG.L', start=start_date, end=end_date)
sns.lineplot(data=data['DBXG.L']['Close'])
# Out:
# [*********************100%%**********************]  1 of 1 completed
# /home/august/.venvs/jupyter/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/august/.venvs/jupyter/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/august/.venvs/jupyter/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...
