# %% [markdown]
# # Testing a Data Generating Process Class

# %% [markdown]
# ### import

# %%
# insert code here
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import seaborn as sns
import importlib
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import pandas as pd
from hmmlearn import hmm
from arch import arch_model
import DGP

# %% [markdown]
# # Testing with constants.

# %%
importlib.reload(DGP)
from DGP import DataGeneratingProcess as dgp

dat = dgp(process_type="Random",n_states = 2)
dat.generate()

# print(generated_data)
# print(generated_data.describe())
# # Access attributes of the instance
# print("Transition Matrix:\n", dgp_instance.transition_matrix)
# print("Mean:", dgp_instance.mean)
# print("Variance:", dgp_instance.variance)
# Out:
# [[0.99753715 0.00581313]
#  [0.00246285 0.99418687]]
#      State         X     Noise     Sigma
# 0        1  0.000000  0.000000  0.000000
# 1        1  0.495038  1.126053  0.173205
# 2        1  0.073730 -1.306368  0.173205
# 3        1  0.080622 -1.266578  0.173205
# 4        1  0.654785  2.048352  0.173205
# ..     ...       ...       ...       ...
# 995      1  0.290378 -0.055552  0.173205
# 996      1  0.287491 -0.072220  0.173205
# 997      1  0.224109 -0.438156  0.173205
# 998      1  0.453118  0.884030  0.173205
# 999      1  0.505453  1.186185  0.173205
#
# [1000 rows x 4 columns]
#              State            X        Noise        Sigma
# count  1000.000000  1000.000000  1000.000000  1000.000000
# mean      0.230000    -0.161221     0.007120     0.116664
# std       0.421043     0.281436     0.997271     0.030992
# min       0.000000    -0.650194    -3.501942     0.000000
# 25%       0.000000    -0.346102    -0.667628     0.100000
# ...
