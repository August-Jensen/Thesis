# %%
import pandas as pd
import numpy as np
import importlib
import Filter

# %%
from Filter import Base
univariates = np.array([[2.65430813e-04, 1.41356236e-01, 8.68148814e-01],
       [3.34238198e-04, 1.51006124e-01, 8.54041060e-01],
       [1.86947446e-04, 7.92241125e-02, 9.17634510e-01],
       [2.38659610e-04, 1.10057866e-01, 8.98490443e-01]])
df = pd.read_csv('A.csv')#.iloc[:250]
model = Base(df, univariates)
model.fit()
# Out:
# First Guess:
# [0.95, 0.95, 0.2989396533731584, 0.3836536339502954, 0.02888821610896346, 0.21241175794572445, 0.08313801929598973, 0.10802150585508526, -0.004621936779375252, 0.07810345281286693, 0.21662894702349708, 0.006584344755960397, 0.20287685801707658, 0.12603972822249895]
# Bounds:
# [(0.01, 0.99), (0.01, 0.99), (-0.9, 0.9), (-0.9, 0.9), (-0.9, 0.9), (-0.9, 0.9), (-0.9, 0.9), (-0.9, 0.9), (-0.9, 0.9), (-0.9, 0.9), (-0.9, 0.9), (-0.9, 0.9), (-0.9, 0.9), (-0.9, 0.9)]
# Standard Deviations:
# [[0.01960613 0.05050282 0.01705012 0.04168559]
#  [0.01850232 0.04573133 0.01827803 0.03963998]
#  [0.02809526 0.0533233  0.01874691 0.0472175 ]
#  [0.02919031 0.04723757 0.01796669 0.04798702]
#  [0.02798976 0.04299281 0.01852733 0.05243158]
#  [0.04305454 0.05285906 0.01806145 0.06599704]
#  [0.06639777 0.07274176 0.01849125 0.0945728 ]
#  [0.07086194 0.07335344 0.02745621 0.09516538]
#  [0.0693058  0.06323231 0.03498892 0.08829465]
#  [0.07751377 0.0672758  0.0433914  0.08984095]
#  [0.08199925 0.07495564 0.04144537 0.08360577]
#  [0.08391143 0.07535624 0.04114232 0.08822721]
#  [0.09011126 0.07899419 0.04387572 0.0972071 ]
#  [0.09259015 0.076377   0.0436718  0.10569128]
#  [0.08392882 0.06651286 0.0405975  0.09793406]
#  [0.08585743 0.06800443 0.03764142 0.09962298]
#  [0.0789364  0.06389036 0.03620981 0.09053139]
#  [0.07550703 0.05944318 0.03508602 0.0920299 ]
#  [0.06968496 0.05403256 0.03473016 0.0856157 ]
#  [0.0681929  0.05550796 0.03275651 0.08479578]
#  [0.06114825 0.04978669 0.03597356 0.07832212]
#  [0.0610441  0.04844425 0.03530218 0.07828026]
#  [0.05629857 0.04634623 0.03313263 0.07262567]
#  [0.05781627 0.04821947 0.03248852 0.07415361]
#  [0.0507838  0.04383384 0.03229402 0.06710022]
#  [0.05826957 0.05027177 0.0334925  0.07112192]
#  [0.05724674 0.05200772 0.03511778 0.06474772]
#  [0.06257979 0.05472782 0.0334073  0.06911661]
#  [0.06077911 0.05402388 0.03697016 0.0651884 ]
#  [0.0662583  0.05861824 0.03636971 0.07071265]
#  [0.0629902  0.0560579  0.03747824 0.06713502]
#  [0.05807469 0.04820999 0.0361801  0.06372703]
#  [0.0599166  0.05048747 0.03691822 0.06363033]
#  [0.05378384 0.04693071 0.03654381 0.06127116]
#  [0.05128312 0.04557149 0.03473906 0.05547976]
#  [0.04600917 0.0398906  0.03229655 0.05595107]
#  [0.04685983 0.03871367 0.03132256 0.05415882]
#  [0.0437348  0.03510033 0.0312577  0.05218934]
#  [0.04241918 0.03362732 0.03102118 0.04823392]
#  [0.04035152 0.03210478 0.0318056  0.04425757]
#  [0.04610235 0.03629162 0.03642051 0.05048646]
#  [0.05587458 0.0429726  0.04319593 0.06803136]
#  [0.06393699 0.05267753 0.04311926 0.07761208]
#  [0.05740456 0.04593792 0.04111035 0.0718702 ]
#  [0.05302059 0.04018201 0.04014434 0.07208541]
#  [0.05383381 0.04149664 0.03728657 0.07627651]
#  [0.05382533 0.04219029 0.03667673 0.07459556]
#  [0.04855978 0.04048661 0.03745219 0.07016046]
#  [0.04404908 0.03592291 0.03808953 0.06560556]
#  [0.05227344 0.0403664  0.04179365 0.07159944]
#  [0.05069786 0.04003531 0.04004255 0.06996462]
#  [0.04543397 0.03630189 0.0397289  0.06332148]
#  [0.04358621 0.03507403 0.03786232 0.05740714]
#  [0.04187856 0.03326537 0.03713205 0.05614975]
#  [0.03735073 0.03151758 0.03481099 0.05129709]
#  [0.03492563 0.02810378 0.03304381 0.0477256 ]
#  [0.03322722 0.02461197 0.03283473 0.04950492]
#  [0.03433532 0.02889256 0.03288186 0.04479249]
#  [0.03021533 0.02692415 0.03116002 0.04310871]
#  [0.0290545  0.02828613 0.02928342 0.04052532]
#  [0.0294441  0.02736542 0.03051394 0.03883473]
#  [0.02637003 0.02722921 0.03390184 0.04086126]
#  [0.02867545 0.02641469 0.03412203 0.04449045]
#  [0.03149022 0.03050205 0.03348883 0.04097632]
#  [0.03088541 0.03098258 0.03218542 0.04089744]
#  [0.03469945 0.03076512 0.03002728 0.04380091]
#  [0.03586624 0.03344444 0.02865896 0.04426481]
#  [0.03357992 0.0333076  0.02886877 0.04104011]
#  [0.03114559 0.03182786 0.02866717 0.03801863]
#  [0.03401123 0.03293532 0.0313352  0.044096  ]
#  [0.03696439 0.03518369 0.02915311 0.04336638]
#  [0.03316063 0.03096506 0.02732465 0.04388461]
#  [0.03072153 0.02782576 0.02670016 0.04064061]
#  [0.02974351 0.02756284 0.02679882 0.04011608]
#  [0.02667489 0.02623794 0.02518222 0.03865561]
#  [0.0254789  0.02478543 0.0236154  0.0364657 ]
#  [0.02598039 0.02734666 0.02530514 0.03715263]
#  [0.02758686 0.02649146 0.02527976 0.04294969]
#  [0.0259087  0.02647413 0.02538946 0.04125553]
#  [0.02468929 0.0270367  0.02560898 0.03852621]
#  [0.02628768 0.02463937 0.02587459 0.04061338]
#  [0.02495999 0.02591909 0.03134842 0.03694963]
#  [0.029514   0.03072751 0.03413207 0.03844716]
#  [0.02796867 0.02963982 0.03221405 0.03725938]
#  [0.0285403  0.02712559 0.03267446 0.04158698]
#  [0.02504266 0.02542959 0.03223483 0.04158629]
#  [0.02734894 0.02588373 0.03323089 0.04146561]
#  [0.02516869 0.02581316 0.03402861 0.04461245]
#  [0.03208058 0.03187601 0.03213374 0.05175245]
#  [0.03306026 0.03224376 0.0310453  0.05145779]
#  [0.03939548 0.04019912 0.02916407 0.05214483]
#  [0.03522321 0.03521687 0.02781177 0.04964692]
#  [0.03567375 0.03393952 0.02627755 0.04923235]
#  [0.03893739 0.03703166 0.0285967  0.05098807]
#  [0.03584494 0.03208557 0.028686   0.04640852]
#  [0.04146853 0.03679034 0.02673432 0.05492708]
#  [0.03814489 0.03234867 0.0254689  0.05069845]
#  [0.03385284 0.03050858 0.02403427 0.04941002]
#  [0.0315773  0.0266491  0.02739038 0.04919358]
#  [0.03291067 0.028503   0.02682414 0.04995257]
#  [0.02932047 0.0248577  0.02575321 0.0459789 ]
#  [0.02704162 0.02231584 0.02516712 0.0424312 ]
#  [0.0264705  0.02203384 0.02697243 0.03871309]
#  [0.0247013  0.02461485 0.03187893 0.03957553]
#  [0.02315054 0.02349945 0.03017491 0.03714207]
#  [0.02441401 0.02308205 0.02851895 0.03977125]
#  [0.02496843 0.02586692 0.02743143 0.03841761]
#  [0.02383132 0.02289254 0.02603211 0.03764815]
#  [0.0232156  0.02137693 0.02514403 0.03576981]
#  [0.02350871 0.02070725 0.02457639 0.03346342]
#  [0.02112704 0.01824407 0.02319631 0.03054809]
#  [0.0224186  0.01898776 0.02215949 0.03341054]
#  [0.02029426 0.01699052 0.02300478 0.03351014]
#  [0.02051681 0.01710972 0.02332191 0.03217591]
#  [0.02108477 0.01846368 0.02177867 0.03179392]
#  [0.02139697 0.02064948 0.02059082 0.02917572]
#  [0.01956855 0.01902022 0.02017594 0.02993536]
#  [0.0250915  0.02485769 0.02132319 0.03617489]
#  [0.02852027 0.02715668 0.02236558 0.03880122]
#  [0.02715804 0.02832768 0.02278451 0.03554539]
#  [0.02441323 0.02530566 0.02293578 0.03526423]
#  [0.0221258  0.02557323 0.02263141 0.03453188]
#  [0.02185865 0.0223642  0.02128041 0.0373776 ]
#  [0.02350982 0.0249273  0.02104039 0.03811856]
#  [0.02165555 0.02636794 0.02035011 0.03920238]
#  [0.01992488 0.02306666 0.02134154 0.03821852]
#  [0.02848172 0.03084736 0.0223036  0.0433467 ]
#  [0.02721569 0.02945454 0.02186484 0.04438044]
#  [0.03586327 0.04028688 0.0243863  0.04461377]
#  [0.04233448 0.04637165 0.02286401 0.05047143]
#  [0.04046275 0.04475485 0.02244459 0.04600904]
#  [0.03760463 0.04060189 0.02491121 0.04388011]
#  [0.03767008 0.0410562  0.02481405 0.04199618]
#  [0.0418216  0.04534852 0.02803213 0.04522872]
#  [0.04369128 0.04848957 0.02649696 0.04587912]
#  [0.03829182 0.04401236 0.02454918 0.04347145]
#  [0.03666726 0.04047236 0.03085945 0.04294126]
#  [0.03523773 0.0371136  0.03079673 0.03920303]
#  [0.03467667 0.03533235 0.02947251 0.03972512]
#  [0.03363407 0.03587907 0.02769324 0.03648219]
#  [0.03254828 0.03456085 0.02843654 0.03914972]
#  [0.03057034 0.02991161 0.0321516  0.04167739]
#  [0.03780924 0.03833425 0.03464201 0.0416598 ]
#  [0.05344263 0.05410046 0.03675608 0.05844399]
#  [0.05991435 0.06459023 0.03476108 0.06102562]
#  [0.05930212 0.06252553 0.03359591 0.05863224]
#  [0.05465437 0.05572509 0.0311802  0.05935546]
#  [0.05509164 0.05656682 0.03214414 0.06263235]
#  [0.05636384 0.0588328  0.03387409 0.05949204]
#  [0.05343158 0.05694592 0.03179191 0.05608352]
#  [0.0498359  0.05278125 0.03217071 0.05207049]
#  [0.05924809 0.0610041  0.03093025 0.05606255]
#  [0.05708497 0.05728531 0.02971156 0.05635848]
#  [0.05026064 0.05080496 0.03038292 0.05427153]
#  [0.04709805 0.04786524 0.03283643 0.05071271]
#  [0.04513101 0.04742386 0.03468252 0.04673001]
#  [0.04532382 0.04862176 0.03385701 0.04417422]
#  [0.04167874 0.04284749 0.03136968 0.04178268]
#  [0.03720515 0.0397838  0.03228472 0.03865485]
#  [0.03384441 0.03795339 0.03260036 0.04165329]
#  [0.03268775 0.03717634 0.03046861 0.04004945]
#  [0.03474831 0.03977435 0.03058385 0.04100297]
#  [0.03785878 0.04454311 0.03008043 0.03850069]
#  [0.03643247 0.0395941  0.02985468 0.03807196]
#  [0.03582369 0.04044665 0.02937977 0.0350484 ]
#  [0.03794416 0.04305931 0.0303099  0.03219561]
#  [0.03760013 0.04163301 0.02941501 0.03334359]
#  [0.03562559 0.04099443 0.03171916 0.03415749]
#  [0.04308438 0.04921691 0.03725636 0.03754143]
#  [0.03829949 0.04270797 0.036315   0.03447483]
#  [0.04677469 0.05045502 0.03466792 0.03635066]
#  [0.05052763 0.05672717 0.03374563 0.03377487]
#  [0.05043879 0.05507214 0.03498878 0.03109229]
#  [0.05799957 0.06263505 0.03926971 0.04134866]
#  [0.05931656 0.06562698 0.04128314 0.04057236]
#  [0.06307951 0.064552   0.04334696 0.05140424]
#  [0.06278798 0.06511916 0.0424468  0.05068929]
#  [0.06500392 0.06515841 0.04497292 0.05459618]
#  [0.061472   0.05982744 0.04559833 0.05687112]
#  [0.05826629 0.05635178 0.04557863 0.05403946]
#  [0.05304943 0.05085422 0.04207848 0.04922934]
#  [0.04780892 0.0444613  0.04142489 0.04777455]
#  [0.04828345 0.04722732 0.03823833 0.04766431]
#  [0.04717656 0.04553206 0.03753176 0.0493478 ]
#  [0.04539291 0.0416948  0.03737467 0.05126698]
#  [0.04585626 0.04381338 0.04128427 0.04994563]
#  [0.0437183  0.0410669  0.04277221 0.04873808]
#  [0.05025444 0.04860647 0.04666066 0.05156841]
#  [0.04920082 0.04797665 0.04909771 0.0478382 ]
#  [0.04336745 0.04369431 0.04703966 0.04720155]]
# The det_R in 0 0.7545294473721746
# The det_R in 1 0.8942811405743738
# Negative Log-Likelihood: -1110.8802367362946
# The det_R in 0 0.7545294473721746
# The det_R in 1 0.8942811405743738
# Negative Log-Likelihood: -1110.880241004215
# The det_R in 0 0.7545294473721746
# The det_R in 1 0.8942811405743738
# Negative Log-Likelihood: -1110.8802356265073
# The det_R in 0 0.7545294430588646
# The det_R in 1 0.8942811405743738
# Negative Log-Likelihood: -1110.8802346416232
# The det_R in 0 0.7545294410206177
# The det_R in 1 0.8942811405743738
# Negative Log-Likelihood: -1110.8802375024268
# The det_R in 0 0.7545294478737139
# The det_R in 1 0.8942811405743738
# Negative Log-Likelihood: -1110.8802353815345
# The det_R in 0 0.7545294455637985
# The det_R in 1 0.8942811405743738
# Negative Log-Likelihood: -1110.8802374239267
# The det_R in 0 0.7545294462909118
# The det_R in 1 0.8942811405743738
# Negative Log-Likelihood: -1110.8802359587855
# The det_R in 0 0.7545294457522744
# The det_R in 1 0.8942811405743738
# Negative Log-Likelihood: -1110.8802366477414
# The det_R in 0 0.7545294473721746
# The det_R in 1 0.8942811415110706
# Negative Log-Likelihood: -1110.8802408846086
# The det_R in 0 0.7545294473721746
# The det_R in 1 0.8942811396186426
# Negative Log-Likelihood: -1110.8802362158303
# The det_R in 0 0.7545294473721746
# The det_R in 1 0.8942811364181019
# Negative Log-Likelihood: -1110.8802392165048
# The det_R in 0 0.7545294473721746
# The det_R in 1 0.8942811408869303
# Negative Log-Likelihood: -1110.8802363196446
# The det_R in 0 0.7545294473721746
# The det_R in 1 0.8942811365368429
# Negative Log-Likelihood: -1110.8802382725364
# The det_R in 0 0.7545294473721746
# The det_R in 1 0.8942811384203353
# Negative Log-Likelihood: -1110.8802366600517
# The det_R in 0 -0.5794999999999999
# The det_R in 1 0.003699999999999998
# Negative Log-Likelihood: 958.081995767535
# The det_R in 0 -0.5794999999999999
# The det_R in 1 0.003699999999999998
# Negative Log-Likelihood: 958.0819712073416
# The det_R in 0 -0.5794999999999999
# The det_R in 1 0.003699999999999998
# Negative Log-Likelihood: 958.0819296047098
# The det_R in 0 -0.5794999933399998
# The det_R in 1 0.003699999999999998
# Negative Log-Likelihood: 958.0819953126569
# The det_R in 0 -0.5794999965799995
# The det_R in 1 0.003699999999999998
# Negative Log-Likelihood: 958.0819951664038
# The det_R in 0 -0.5794999965799998
# The det_R in 1 0.003699999999999998
# Negative Log-Likelihood: 958.0819958590479
# The det_R in 0 -0.5794999965800002
# The det_R in 1 0.003699999999999998
# Negative Log-Likelihood: 958.0819948247919
# The det_R in 0 -0.5794999965799998
# The det_R in 1 0.003699999999999998
# Negative Log-Likelihood: 958.0819961966296
# The det_R in 0 -0.5795000581400003
# The det_R in 1 0.003699999999999998
# Negative Log-Likelihood: 958.0819661345328
# The det_R in 0 -0.5794999999999999
# The det_R in 1 0.003700000179999976
# Negative Log-Likelihood: 958.0820347057625
# The det_R in 0 -0.5794999999999999
# The det_R in 1 0.003700000179999983
# Negative Log-Likelihood: 958.0818988649481
# The det_R in 0 -0.5794999999999999
# The det_R in 1 0.0037000001799999795
# Negative Log-Likelihood: 958.082017665253
# The det_R in 0 -0.5794999999999999
# The det_R in 1 0.003700000179999983
# Negative Log-Likelihood: 958.0819190301927
# The det_R in 0 -0.5794999999999999
# The det_R in 1 0.003700000179999983
# Negative Log-Likelihood: 958.0819950849423
# The det_R in 0 -0.5794999999999999
# The det_R in 1 0.0037000001799999795
# Negative Log-Likelihood: 958.0819135570844
# The det_R in 0 0.1800251309119757
# The det_R in 1 0.4688324359864647
# Negative Log-Likelihood: -1177.7757478411404
# The det_R in 0 0.1800251309119757
# The det_R in 1 0.4688324359864647
# Negative Log-Likelihood: -1177.7757483960154
# The det_R in 0 0.1800251309119757
# The det_R in 1 0.4688324359864647
# Negative Log-Likelihood: -1177.7757507049587
# The det_R in 0 0.1800251401005851
# The det_R in 1 0.4688324359864647
# Negative Log-Likelihood: -1177.7757477410457
# The det_R in 0 0.18002511978158875
# The det_R in 1 0.4688324359864647
# Negative Log-Likelihood: -1177.775747887565
# The det_R in 0 0.18002513506205414
# The det_R in 1 0.4688324359864647
# Negative Log-Likelihood: -1177.775747762294
# The det_R in 0 0.18002512108170154
# The det_R in 1 0.4688324359864647
# Negative Log-Likelihood: -1177.7757478826318
# The det_R in 0 0.18002513468166384
# The det_R in 1 0.4688324359864647
# Negative Log-Likelihood: -1177.7757477688085
# The det_R in 0 0.18002512822425226
# The det_R in 1 0.4688324359864647
# Negative Log-Likelihood: -1177.7757478697959
# The det_R in 0 0.1800251309119757
# The det_R in 1 0.4688324345177679
# Negative Log-Likelihood: -1177.7757502301774
# The det_R in 0 0.1800251309119757
# The det_R in 1 0.46883243812592135
# Negative Log-Likelihood: -1177.7757493910995
# The det_R in 0 0.1800251309119757
# The det_R in 1 0.4688324308705627
# Negative Log-Likelihood: -1177.7757488189095
# The det_R in 0 0.1800251309119757
# The det_R in 1 0.4688324388913649
# Negative Log-Likelihood: -1177.7757493670083
# The det_R in 0 0.1800251309119757
# The det_R in 1 0.46883243110920736
# Negative Log-Likelihood: -1177.775747947116
# The det_R in 0 0.1800251309119757
# The det_R in 1 0.4688324367795552
# Negative Log-Likelihood: -1177.7757485801703
# The det_R in 0 0.16904127852507358
# The det_R in 1 0.30816961603197573
# Negative Log-Likelihood: -1380.2561799491655
# The det_R in 0 0.16904127852507358
# The det_R in 1 0.30816961603197573
# Negative Log-Likelihood: -1380.256178804892
# The det_R in 0 0.16904127852507358
# The det_R in 1 0.30816961603197573
# Negative Log-Likelihood: -1380.2561820648357
# The det_R in 0 0.16904128817951797
# The det_R in 1 0.30816961603197573
# Negative Log-Likelihood: -1380.2561799395369
# The det_R in 0 0.1690412669069846
# The det_R in 1 0.30816961603197573
# Negative Log-Likelihood: -1380.25617994996
# The det_R in 0 0.16904128322105036
# The det_R in 1 0.30816961603197573
# Negative Log-Likelihood: -1380.2561799375164
# The det_R in 0 0.16904126838876385
# The det_R in 1 0.30816961603197573
# Negative Log-Likelihood: -1380.2561799481002
# The det_R in 0 0.16904128267760601
# The det_R in 1 0.30816961603197573
# Negative Log-Likelihood: -1380.2561799395328
# The det_R in 0 0.16904127510691738
# The det_R in 1 0.30816961603197573
# Negative Log-Likelihood: -1380.2561799496602
# The det_R in 0 0.16904127852507358
# The det_R in 1 0.30816960897925777
# Negative Log-Likelihood: -1380.256182503109
# The det_R in 0 0.16904127852507358
# The det_R in 1 0.30816961566438866
# Negative Log-Likelihood: -1380.256179801093
# The det_R in 0 0.16904127852507358
# The det_R in 1 0.3081696104615254
# Negative Log-Likelihood: -1380.2561811657356
# The det_R in 0 0.16904127852507358
# The det_R in 1 0.30816961691282
# Negative Log-Likelihood: -1380.2561800919989
# The det_R in 0 0.16904127852507358
# The det_R in 1 0.3081696146938933
# Negative Log-Likelihood: -1380.256179549629
# The det_R in 0 0.16904127852507358
# The det_R in 1 0.3081696168778947
# Negative Log-Likelihood: -1380.25618062016
# The det_R in 0 0.1480719205257328
# The det_R in 1 -0.054138504624385124
# Negative Log-Likelihood: -212.09299700945158
# The det_R in 0 0.1480719205257328
# The det_R in 1 -0.054138504624385124
# Negative Log-Likelihood: -212.0929699885147
# The det_R in 0 0.1480719205257328
# The det_R in 1 -0.054138504624385124
# Negative Log-Likelihood: -212.09303913575627
# The det_R in 0 0.14807193045453385
# The det_R in 1 -0.054138504624385124
# Negative Log-Likelihood: -212.09298730186057
# The det_R in 0 0.14807190879275872
# The det_R in 1 -0.054138504624385124
# Negative Log-Likelihood: -212.09300676262706
# The det_R in 0 0.14807192541691902
# The det_R in 1 -0.054138504624385124
# Negative Log-Likelihood: -212.09299186150838
# The det_R in 0 0.1480719102614281
# The det_R in 1 -0.054138504624385124
# Negative Log-Likelihood: -212.09300577323327
# The det_R in 0 0.1480719248525102
# The det_R in 1 -0.054138504624385124
# Negative Log-Likelihood: -212.09299244912262
# The det_R in 0 0.14807191679394174
# The det_R in 1 -0.054138504624385124
# Negative Log-Likelihood: -212.09300140265296
# The det_R in 0 0.1480719205257328
# The det_R in 1 -0.05413849439501279
# Negative Log-Likelihood: -212.09304174682362
# The det_R in 0 0.1480719205257328
# The det_R in 1 -0.054138504510090404
# Negative Log-Likelihood: -212.0929974501614
# The det_R in 0 0.1480719205257328
# The det_R in 1 -0.05413851365019746
# Negative Log-Likelihood: -212.09296612293835
# The det_R in 0 0.1480719205257328
# The det_R in 1 -0.05413850478590519
# Negative Log-Likelihood: -212.09299692614078
# The det_R in 0 0.1480719205257328
# The det_R in 1 -0.054138498199937164
# Negative Log-Likelihood: -212.09301710356084
# The det_R in 0 0.1480719205257328
# The det_R in 1 -0.05413850468459461
# Negative Log-Likelihood: -212.09299697467068
# The det_R in 0 0.1682579060554303
# The det_R in 1 0.2982179612901352
# Negative Log-Likelihood: -1384.6853382052482
# The det_R in 0 0.1682579060554303
# The det_R in 1 0.2982179612901352
# Negative Log-Likelihood: -1384.6853370912947
# The det_R in 0 0.1682579060554303
# The det_R in 1 0.2982179612901352
# Negative Log-Likelihood: -1384.6853403123323
# The det_R in 0 0.1682579157202227
# The det_R in 1 0.2982179612901352
# Negative Log-Likelihood: -1384.685338195808
# The det_R in 0 0.16825789443301026
# The det_R in 1 0.2982179612901352
# Negative Log-Likelihood: -1384.6853382063546
# The det_R in 0 0.16825791075875982
# The det_R in 1 0.2982179612901352
# Negative Log-Likelihood: -1384.6853381939507
# The det_R in 0 0.16825789591429344
# The det_R in 1 0.2982179612901352
# Negative Log-Likelihood: -1384.6853382045006
# The det_R in 0 0.168257910214512
# The det_R in 1 0.2982179612901352
# Negative Log-Likelihood: -1384.6853381959356
# The det_R in 0 0.16825790262549237
# The det_R in 1 0.2982179612901352
# Negative Log-Likelihood: -1384.6853382060574
# The det_R in 0 0.1682579060554303
# The det_R in 1 0.2982179541226903
# Negative Log-Likelihood: -1384.6853408228546
# The det_R in 0 0.1682579060554303
# The det_R in 1 0.2982179609197344
# Negative Log-Likelihood: -1384.6853380394832
# The det_R in 0 0.1682579060554303
# The det_R in 1 0.2982179555970334
# Negative Log-Likelihood: -1384.6853394333832
# The det_R in 0 0.1682579060554303
# The det_R in 1 0.2982179621454424
# Negative Log-Likelihood: -1384.6853383500436
# The det_R in 0 0.1682579060554303
# The det_R in 1 0.29821796019924374
# Negative Log-Likelihood: -1384.6853377866278
# The det_R in 0 0.1682579060554303
# The det_R in 1 0.29821796208844004
# Negative Log-Likelihood: -1384.6853388602794
# The det_R in 0 0.15823282200199298
# The det_R in 1 0.14642148742561362
# Negative Log-Likelihood: -1444.6162478542751
# The det_R in 0 0.15823282200199298
# The det_R in 1 0.14642148742561362
# Negative Log-Likelihood: -1444.6162471035514
# The det_R in 0 0.15823282200199298
# The det_R in 1 0.14642148742561362
# Negative Log-Likelihood: -1444.6162498577528
# The det_R in 0 0.1582328317985288
# The det_R in 1 0.14642148742561362
# Negative Log-Likelihood: -1444.616247845127
# The det_R in 0 0.1582328103244175
# The det_R in 1 0.14642148742561362
# Negative Log-Likelihood: -1444.616247860939
# The det_R in 0 0.1582328267990017
# The det_R in 1 0.14642148742561362
# Negative Log-Likelihood: -1444.6162478446145
# The det_R in 0 0.15823281179939647
# The det_R in 1 0.14642148742561362
# Negative Log-Likelihood: -1444.6162478585497
# The det_R in 0 0.1582328262446126
# The det_R in 1 0.14642148742561362
# Negative Log-Likelihood: -1444.6162478466588
# The det_R in 0 0.15823281842173006
# The det_R in 1 0.14642148742561362
# Negative Log-Likelihood: -1444.6162478599524
# The det_R in 0 0.15823282200199298
# The det_R in 1 0.14642147875872275
# Negative Log-Likelihood: -1444.616251210381
# The det_R in 0 0.15823282200199298
# The det_R in 1 0.14642148715713052
# Negative Log-Likelihood: -1444.6162474132939
# The det_R in 0 0.15823282200199298
# The det_R in 1 0.1464214801197053
# Negative Log-Likelihood: -1444.616248424889
# The det_R in 0 0.15823282200199298
# The det_R in 1 0.146421487865043
# Negative Log-Likelihood: -1444.6162480753278
# The det_R in 0 0.15823282200199298
# The det_R in 1 0.14642148980074726
# Negative Log-Likelihood: -1444.616247531878
# The det_R in 0 0.15823282200199298
# The det_R in 1 0.14642148770384858
# Negative Log-Likelihood: -1444.616248381471
# The det_R in 0 0.151541909478566
# The det_R in 1 0.019666693731345334
# Negative Log-Likelihood: -1178.2248309686095
# The det_R in 0 0.151541909478566
# The det_R in 1 0.019666693731345334
# Negative Log-Likelihood: -1178.2248257154895
# The det_R in 0 0.151541909478566
# The det_R in 1 0.019666693731345334
# Negative Log-Likelihood: -1178.2248317401163
# The det_R in 0 0.1515419193623381
# The det_R in 1 0.019666693731345334
# Negative Log-Likelihood: -1178.224829826096
# The det_R in 0 0.1515418977644547
# The det_R in 1 0.019666693731345334
# Negative Log-Likelihood: -1178.2248317932253
# The det_R in 0 0.15154191433767591
# The det_R in 1 0.019666693731345334
# Negative Log-Likelihood: -1178.2248300292151
# The det_R in 0 0.1515418992352698
# The det_R in 1 0.019666693731345334
# Negative Log-Likelihood: -1178.224831708378
# The det_R in 0 0.15154191377666013
# The det_R in 1 0.019666693731345334
# Negative Log-Likelihood: -1178.2248301290479
# The det_R in 0 0.15154190579842963
# The det_R in 1 0.019666693731345334
# Negative Log-Likelihood: -1178.2248315903116
# The det_R in 0 0.151541909478566
# The det_R in 1 0.01966668403897065
# Negative Log-Likelihood: -1178.2246078458234
# The det_R in 0 0.151541909478566
# The det_R in 1 0.019666693681687355
# Negative Log-Likelihood: -1178.2248277857648
# The det_R in 0 0.151541909478566
# The det_R in 1 0.019666685302838566
# Negative Log-Likelihood: -1178.2246147699836
# The det_R in 0 0.151541909478566
# The det_R in 1 0.01966669379630356
# Negative Log-Likelihood: -1178.2248328921314
# The det_R in 0 0.151541909478566
# The det_R in 1 0.01966669871542034
# Negative Log-Likelihood: -1178.2249620328932
# The det_R in 0 0.151541909478566
# The det_R in 1 0.019666693763646846
# Negative Log-Likelihood: -1178.2248329057577
# The det_R in 0 0.15602580055482665
# The det_R in 1 0.10687219230515088
# Negative Log-Likelihood: -1453.9946168135452
# The det_R in 0 0.15602580055482665
# The det_R in 1 0.10687219230515088
# Negative Log-Likelihood: -1453.9946161117095
# The det_R in 0 0.15602580055482665
# The det_R in 1 0.10687219230515088
# Negative Log-Likelihood: -1453.9946187957241
# The det_R in 0 0.15602581038019794
# The det_R in 1 0.10687219230515088
# Negative Log-Likelihood: -1453.9946168023007
# The det_R in 0 0.15602578886517568
# The det_R in 1 0.10687219230515088
# Negative Log-Likelihood: -1453.9946168241624
# The det_R in 0 0.1560258053723565
# The det_R in 1 0.10687219230515088
# Negative Log-Likelihood: -1453.9946168018328
# The det_R in 0 0.15602579033877723
# The det_R in 1 0.10687219230515088
# Negative Log-Likelihood: -1453.9946168208885
# The det_R in 0 0.15602580481576916
# The det_R in 1 0.10687219230515088
# Negative Log-Likelihood: -1453.9946168044034
# The det_R in 0 0.15602579694158025
# The det_R in 1 0.10687219230515088
# Negative Log-Likelihood: -1453.994616822472
# The det_R in 0 0.15602580055482665
# The det_R in 1 0.1068721833017349
# Negative Log-Likelihood: -1453.9946191492304
# The det_R in 0 0.15602580055482665
# The det_R in 1 0.10687219209499832
# Negative Log-Likelihood: -1453.9946162542196
# The det_R in 0 0.15602580055482665
# The det_R in 1 0.10687218463313176
# Negative Log-Likelihood: -1453.9946155673779
# The det_R in 0 0.15602580055482665
# The det_R in 1 0.1068721926299324
# Negative Log-Likelihood: -1453.994617092094
# The det_R in 0 0.15602580055482665
# The det_R in 1 0.10687219551570415
# Negative Log-Likelihood: -1453.9946174118427
# The det_R in 0 0.15602580055482665
# The det_R in 1 0.10687219249276922
# Negative Log-Likelihood: -1453.994617353946
# The det_R in 0 0.13544544594918811
# The det_R in 1 0.056634872500664686
# Negative Log-Likelihood: -1471.0743975207056
# The det_R in 0 0.13544544594918811
# The det_R in 1 0.056634872500664686
# Negative Log-Likelihood: -1471.0743970000108
# The det_R in 0 0.13544544594918811
# The det_R in 1 0.056634872500664686
# Negative Log-Likelihood: -1471.074395610918
# The det_R in 0 0.135445456029501
# The det_R in 1 0.056634872500664686
# Negative Log-Likelihood: -1471.07439751121
# The det_R in 0 0.13544543414366067
# The det_R in 1 0.056634872500664686
# Negative Log-Likelihood: -1471.0743975295359
# The det_R in 0 0.13544545090387422
# The det_R in 1 0.056634872500664686
# Negative Log-Likelihood: -1471.0743975123667
# The det_R in 0 0.13544543560089176
# The det_R in 1 0.056634872500664686
# Negative Log-Likelihood: -1471.074397527549
# The det_R in 0 0.13544545033405053
# The det_R in 1 0.056634872500664686
# Negative Log-Likelihood: -1471.0743975140135
# The det_R in 0 0.13544544207771028
# The det_R in 1 0.056634872500664686
# Negative Log-Likelihood: -1471.0743975268101
# The det_R in 0 0.13544544594918811
# The det_R in 1 0.05663488298881569
# Negative Log-Likelihood: -1471.0744047778142
# The det_R in 0 0.13544544594918811
# The det_R in 1 0.05663487293876277
# Negative Log-Likelihood: -1471.0743992843131
# The det_R in 0 0.13544544594918811
# The det_R in 1 0.05663486671353544
# Negative Log-Likelihood: -1471.0743922198021
# The det_R in 0 0.13544544594918811
# The det_R in 1 0.05663487228151628
# Negative Log-Likelihood: -1471.074396182578
# The det_R in 0 0.13544544594918811
# The det_R in 1 0.056634875818285635
# Negative Log-Likelihood: -1471.074401559802
# The det_R in 0 0.13544544594918811
# The det_R in 1 0.056634872336075504
# Negative Log-Likelihood: -1471.0743969009222
# The det_R in 0 0.1453989364631492
# The det_R in 1 0.0834766431266734
# Negative Log-Likelihood: -1469.858021348688
# The det_R in 0 0.1453989364631492
# The det_R in 1 0.0834766431266734
# Negative Log-Likelihood: -1469.8580207514892
# The det_R in 0 0.1453989364631492
# The det_R in 1 0.0834766431266734
# Negative Log-Likelihood: -1469.858023292637
# The det_R in 0 0.14539894642070053
# The det_R in 1 0.0834766431266734
# Negative Log-Likelihood: -1469.8580213387486
# The det_R in 0 0.14539892471345198
# The det_R in 1 0.0834766431266734
# Negative Log-Likelihood: -1469.8580213579544
# The det_R in 0 0.14539894135174164
# The det_R in 1 0.0834766431266734
# Negative Log-Likelihood: -1469.8580213389764
# The det_R in 0 0.1453989261785191
# The det_R in 1 0.0834766431266734
# Negative Log-Likelihood: -1469.858021355415
# The det_R in 0 0.14539894078818394
# The det_R in 1 0.0834766431266734
# Negative Log-Likelihood: -1469.8580213410125
# The det_R in 0 0.14539893271653634
# The det_R in 1 0.0834766431266734
# Negative Log-Likelihood: -1469.858021356089
# The det_R in 0 0.1453989364631492
# The det_R in 1 0.08347663335865922
# Negative Log-Likelihood: -1469.8580222089508
# The det_R in 0 0.1453989364631492
# The det_R in 1 0.08347664326179528
# Negative Log-Likelihood: -1469.8580215289212
# The det_R in 0 0.1453989364631492
# The det_R in 1 0.08347663641920647
# Negative Log-Likelihood: -1469.8580195843335
# The det_R in 0 0.1453989364631492
# The det_R in 1 0.08347664318301476
# Negative Log-Likelihood: -1469.8580211676358
# The det_R in 0 0.1453989364631492
# The det_R in 1 0.08347664639491659
# Negative Log-Likelihood: -1469.8580225461487
# The det_R in 0 0.1453989364631492
# The det_R in 1 0.08347664310211181
# Negative Log-Likelihood: -1469.8580214166263
# The det_R in 0 0.17875485562350077
# The det_R in 1 0.11846152003748606
# Negative Log-Likelihood: -1412.1279350704162
# The det_R in 0 0.17875485562350077
# The det_R in 1 0.11846152003748606
# Negative Log-Likelihood: -1412.1279340514593
# The det_R in 0 0.17875485562350077
# The det_R in 1 0.11846152003748606
# Negative Log-Likelihood: -1412.1279331606547
# The det_R in 0 0.1787548652488631
# The det_R in 1 0.11846152003748606
# Negative Log-Likelihood: -1412.127935059903
# The det_R in 0 0.17875484391043314
# The det_R in 1 0.11846152003748606
# Negative Log-Likelihood: -1412.1279350777313
# The det_R in 0 0.17875486044763117
# The det_R in 1 0.11846152003748606
# Negative Log-Likelihood: -1412.127935064504
# The det_R in 0 0.17875484548234652
# The det_R in 1 0.11846152003748606
# Negative Log-Likelihood: -1412.127935077015
# The det_R in 0 0.17875485984892628
# The det_R in 1 0.11846152003748606
# Negative Log-Likelihood: -1412.1279350679033
# The det_R in 0 0.1787548520862137
# The det_R in 1 0.11846152003748606
# Negative Log-Likelihood: -1412.1279350722643
# The det_R in 0 0.17875485562350077
# The det_R in 1 0.11846153167236512
# Negative Log-Likelihood: -1412.1279385524513
# The det_R in 0 0.17875485562350077
# The det_R in 1 0.11846152142233043
# Negative Log-Likelihood: -1412.1279374713436
# The det_R in 0 0.17875485562350077
# The det_R in 1 0.11846151968983634
# Negative Log-Likelihood: -1412.1279392726804
# The det_R in 0 0.17875485562350077
# The det_R in 1 0.11846151904765749
# Negative Log-Likelihood: -1412.1279327566149
# The det_R in 0 0.17875485562350077
# The det_R in 1 0.11846151827592293
# Negative Log-Likelihood: -1412.1279316655246
# The det_R in 0 0.17875485562350077
# The det_R in 1 0.11846151986457483
# Negative Log-Likelihood: -1412.1279353000052
# The det_R in 0 0.1529889091620254
# The det_R in 1 0.10966696601546873
# Negative Log-Likelihood: -1471.0506779081616
# The det_R in 0 0.1529889091620254
# The det_R in 1 0.10966696601546873
# Negative Log-Likelihood: -1471.0506772948224
# The det_R in 0 0.1529889091620254
# The det_R in 1 0.10966696601546873
# Negative Log-Likelihood: -1471.0506798444212
# The det_R in 0 0.15298891904551318
# The det_R in 1 0.10966696601546873
# Negative Log-Likelihood: -1471.0506779016923
# The det_R in 0 0.15298889741978064
# The det_R in 1 0.10966696601546873
# Negative Log-Likelihood: -1471.0506779126495
# The det_R in 0 0.15298891403629752
# The det_R in 1 0.10966696601546873
# Negative Log-Likelihood: -1471.0506779019902
# The det_R in 0 0.15298889890880393
# The det_R in 1 0.10966696601546873
# Negative Log-Likelihood: -1471.050677911228
# The det_R in 0 0.1529889134650965
# The det_R in 1 0.10966696601546873
# Negative Log-Likelihood: -1471.0506779034258
# The det_R in 0 0.15298890546487526
# The det_R in 1 0.10966696601546873
# Negative Log-Likelihood: -1471.050677911553
# The det_R in 0 0.1529889091620254
# The det_R in 1 0.109666955892965
# Negative Log-Likelihood: -1471.05068082438
# The det_R in 0 0.1529889091620254
# The det_R in 1 0.10966696652578532
# Negative Log-Likelihood: -1471.0506786331453
# The det_R in 0 0.1529889091620254
# The det_R in 1 0.10966696074415674
# Negative Log-Likelihood: -1471.0506791884927
# The det_R in 0 0.1529889091620254
# The det_R in 1 0.10966696585472804
# Negative Log-Likelihood: -1471.0506773473448
# The det_R in 0 0.1529889091620254
# The det_R in 1 0.10966696813847976
# Negative Log-Likelihood: -1471.050677358394
# The det_R in 0 0.1529889091620254
# The det_R in 1 0.10966696584277728
# Negative Log-Likelihood: -1471.0506777513501
# The det_R in 0 -0.005209609534670806
# The det_R in 1 0.09423615655036408
# /home/august/code/jupyter/Thesis/Filter.py:395: RuntimeWarning: overflow encountered in exp
#   return np.exp(log_likelihood_contribution)
# /home/august/code/jupyter/Thesis/Filter.py:464: RuntimeWarning: invalid value encountered in scalar divide
#   filter_0 = eta[0]*self.predicted_probabilities[0,t]/(eta[0]*self.predicted_probabilities[0,t]+eta[1]*self.predicted_probabilities[1,t])
# Negative Log-Likelihood: nan
# The det_R in 0 -0.005209609534670806
# The det_R in 1 0.09423615655036408
# Negative Log-Likelihood: nan
# The det_R in 0 -0.005209609534670806
# The det_R in 1 0.09423615655036408
# Negative Log-Likelihood: nan
# The det_R in 0 -0.005209598019869276
# The det_R in 1 0.09423615655036408
# Negative Log-Likelihood: nan
# The det_R in 0 -0.005209621766952323
# The det_R in 1 0.09423615655036408
# Negative Log-Likelihood: nan
# The det_R in 0 -0.00520960405751393
# The det_R in 1 0.09423615655036408
# Negative Log-Likelihood: nan
# The det_R in 0 -0.005209620560381257
# The det_R in 1 0.09423615655036408
# Negative Log-Likelihood: nan
# The det_R in 0 -0.005209604599439227
# The det_R in 1 0.09423615655036408
# Negative Log-Likelihood: nan
# The det_R in 0 -0.0052096148299961035
# The det_R in 1 0.09423615655036408
# Negative Log-Likelihood: nan
# The det_R in 0 -0.005209609534670806
# The det_R in 1 0.0942361664030301
# Negative Log-Likelihood: nan
# The det_R in 0 -0.005209609534670806
# The det_R in 1 0.09423615664536365
# Negative Log-Likelihood: nan
# The det_R in 0 -0.005209609534670806
# The det_R in 1 0.09423615305400508
# Negative Log-Likelihood: nan
# The det_R in 0 -0.005209609534670806
# The det_R in 1 0.09423615662281183
# Negative Log-Likelihood: nan
# The det_R in 0 -0.005209609534670806
# The det_R in 1 0.09423615754750464
# Negative Log-Likelihood: nan
# The det_R in 0 -0.005209609534670806
# The det_R in 1 0.09423615663213279
# Negative Log-Likelihood: nan
# The det_R in 0 -5.415045492493068
# The det_R in 1 -11.6603
# Negative Log-Likelihood: 194.31351314886507
# The det_R in 0 -5.415045492493068
# The det_R in 1 -11.6603
# Negative Log-Likelihood: 194.31351259044942
# The det_R in 0 -5.415045492493068
# The det_R in 1 -11.6603
# Negative Log-Likelihood: 194.31335321893226
# The det_R in 0 -5.415045445024844
# The det_R in 1 -11.6603
# Negative Log-Likelihood: 194.3135136067752
# The det_R in 0 -5.4150454581025596
# The det_R in 1 -11.6603
# Negative Log-Likelihood: 194.31351339434235
# The det_R in 0 -5.41504545877579
# The det_R in 1 -11.6603
# Negative Log-Likelihood: 194.31351368488913
# The det_R in 0 -5.415045526044405
# The det_R in 1 -11.6603
# Negative Log-Likelihood: 194.3135129195083
# The det_R in 0 -5.415045458722173
# The det_R in 1 -11.6603
# Negative Log-Likelihood: 194.3135134926194
# The det_R in 0 -5.4150455452375015
# The det_R in 1 -11.6603
# Negative Log-Likelihood: 194.31351409656116
# The det_R in 0 -5.415045492493068
# The det_R in 1 -11.660299935020003
# Negative Log-Likelihood: 194.31351325411305
# The det_R in 0 -5.415045492493068
# The det_R in 1 -11.660299935020003
# Negative Log-Likelihood: 194.3135129617111
# The det_R in 0 -5.415045492493068
# The det_R in 1 -11.660299935020003
# Negative Log-Likelihood: 194.31351334742072
# The det_R in 0 -5.415045492493068
# The det_R in 1 -11.660299935020003
# Negative Log-Likelihood: 194.3135137971429
# The det_R in 0 -5.415045492493068
# The det_R in 1 -11.660299935020003
# Negative Log-Likelihood: 194.313512565147
# The det_R in 0 -5.415045492493068
# The det_R in 1 -11.660299935020003
# Negative Log-Likelihood: 194.31351380023793
# The det_R in 0 0.10634570210465784
# The det_R in 1 0.09834836378726182
# Negative Log-Likelihood: -1473.4607341417113
# The det_R in 0 0.10634570210465784
# The det_R in 1 0.09834836378726182
# Negative Log-Likelihood: -1473.4607335938786
# The det_R in 0 0.10634570210465784
# The det_R in 1 0.09834836378726182
# Negative Log-Likelihood: -1473.4607360771765
# The det_R in 0 0.10634571257922346
# The det_R in 1 0.09834836378726182
# Negative Log-Likelihood: -1473.4607341338938
# The det_R in 0 0.10634569007148738
# The det_R in 1 0.09834836378726182
# Negative Log-Likelihood: -1473.4607341454475
# The det_R in 0 0.10634570741366944
# The det_R in 1 0.09834836378726182
# Negative Log-Likelihood: -1473.4607341354322
# The det_R in 0 0.10634569152420836
# The det_R in 1 0.09834836378726182
# Negative Log-Likelihood: -1473.460734145066
# The det_R in 0 0.10634570680458784
# The det_R in 1 0.09834836378726182
# Negative Log-Likelihood: -1473.4607341361157
# The det_R in 0 0.10634569767827864
# The det_R in 1 0.09834836378726182
# Negative Log-Likelihood: -1473.4607341442807
# The det_R in 0 0.10634570210465784
# The det_R in 1 0.09834835320976003
# Negative Log-Likelihood: -1473.4607363381435
# The det_R in 0 0.10634570210465784
# The det_R in 1 0.09834836360172665
# Negative Log-Likelihood: -1473.4607337562366
# The det_R in 0 0.10634570210465784
# The det_R in 1 0.09834835787537714
# Negative Log-Likelihood: -1473.4607346164066
# The det_R in 0 0.10634570210465784
# The det_R in 1 0.09834836410715674
# Negative Log-Likelihood: -1473.460734370804
# The det_R in 0 0.10634570210465784
# The det_R in 1 0.09834836666857243
# Negative Log-Likelihood: -1473.4607342664572
# The det_R in 0 0.10634570210465784
# The det_R in 1 0.09834836390282273
# Negative Log-Likelihood: -1473.4607344664914
# The det_R in 0 0.13646259907625563
# The det_R in 1 0.06579515080539952
# Negative Log-Likelihood: -1477.4818053969148
# The det_R in 0 0.13646259907625563
# The det_R in 1 0.06579515080539952
# Negative Log-Likelihood: -1477.4818048834113
# The det_R in 0 0.13646259907625563
# The det_R in 1 0.06579515080539952
# Negative Log-Likelihood: -1477.4818034870818
# The det_R in 0 0.13646260917174907
# The det_R in 1 0.06579515080539952
# Negative Log-Likelihood: -1477.4818053896831
# The det_R in 0 0.13646258722991003
# The det_R in 1 0.06579515080539952
# Negative Log-Likelihood: -1477.4818054023065
# The det_R in 0 0.1364626041061818
# The det_R in 1 0.06579515080539952
# Negative Log-Likelihood: -1477.4818053906952
# The det_R in 0 0.13646258870585695
# The det_R in 1 0.06579515080539952
# Negative Log-Likelihood: -1477.4818054011116
# The det_R in 0 0.13646260352101947
# The det_R in 1 0.06579515080539952
# Negative Log-Likelihood: -1477.48180539186
# The det_R in 0 0.13646259511805198
# The det_R in 1 0.06579515080539952
# Negative Log-Likelihood: -1477.481805400671
# The det_R in 0 0.13646259907625563
# The det_R in 1 0.06579516156745334
# Negative Log-Likelihood: -1477.4818086342116
# The det_R in 0 0.13646259907625563
# The det_R in 1 0.06579515109308606
# Negative Log-Likelihood: -1477.481806316577
# The det_R in 0 0.13646259907625563
# The det_R in 1 0.06579514530111946
# Negative Log-Likelihood: -1477.4818032331182
# The det_R in 0 0.13646259907625563
# The det_R in 1 0.06579515072033823
# Negative Log-Likelihood: -1477.4818046825155
# The det_R in 0 0.13646259907625563
# The det_R in 1 0.06579515389707782
# Negative Log-Likelihood: -1477.4818074123325
# The det_R in 0 0.13646259907625563
# The det_R in 1 0.06579515070710762
# Negative Log-Likelihood: -1477.4818051559205
# The det_R in 0 0.14428022625871265
# The det_R in 1 0.08478757113920327
# Negative Log-Likelihood: -1479.5949635068448
# The det_R in 0 0.14428022625871265
# The det_R in 1 0.08478757113920327
# Negative Log-Likelihood: -1479.5949629541005
# The det_R in 0 0.14428022625871265
# The det_R in 1 0.08478757113920327
# Negative Log-Likelihood: -1479.594961596875
# The det_R in 0 0.1442802362542218
# The det_R in 1 0.08478757113920327
# Negative Log-Likelihood: -1479.594963500378
# The det_R in 0 0.1442802144613947
# The det_R in 1 0.08478757113920327
# Negative Log-Likelihood: -1479.5949635113557
# The det_R in 0 0.1442802312151156
# The det_R in 1 0.08478757113920327
# Negative Log-Likelihood: -1479.5949635010434
# The det_R in 0 0.14428021594358045
# The det_R in 1 0.08478757113920327
# Negative Log-Likelihood: -1479.594963510167
# The det_R in 0 0.14428023063646872
# The det_R in 1 0.08478757113920327
# Negative Log-Likelihood: -1479.594963502274
# The det_R in 0 0.14428022242372213
# The det_R in 1 0.08478757113920327
# Negative Log-Likelihood: -1479.5949635101451
# The det_R in 0 0.14428022625871265
# The det_R in 1 0.0847875606626019
# Negative Log-Likelihood: -1479.594964646803
# The det_R in 0 0.14428022625871265
# The det_R in 1 0.08478757146169436
# Negative Log-Likelihood: -1479.594964186077
# The det_R in 0 0.14428022625871265
# The det_R in 1 0.08478756585653792
# Negative Log-Likelihood: -1479.5949638537081
# The det_R in 0 0.14428022625871265
# The det_R in 1 0.08478757106859575
# Negative Log-Likelihood: -1479.5949629744823
# The det_R in 0 0.14428022625871265
# The det_R in 1 0.08478757373484884
# Negative Log-Likelihood: -1479.5949636548817
# The det_R in 0 0.14428022625871265
# The det_R in 1 0.08478757102890927
# Negative Log-Likelihood: -1479.5949633597124
# The det_R in 0 0.1347040365327714
# The det_R in 1 0.08175682368682205
# Negative Log-Likelihood: -1480.1555618267932
# The det_R in 0 0.1347040365327714
# The det_R in 1 0.08175682368682205
# Negative Log-Likelihood: -1480.1555612882757
# The det_R in 0 0.1347040365327714
# The det_R in 1 0.08175682368682205
# Negative Log-Likelihood: -1480.1555599168612
# The det_R in 0 0.13470404665061014
# The det_R in 1 0.08175682368682205
# Negative Log-Likelihood: -1480.1555618201096
# The det_R in 0 0.1347040246753075
# The det_R in 1 0.08175682368682205
# Negative Log-Likelihood: -1480.1555618311372
# The det_R in 0 0.13470404157907695
# The det_R in 1 0.08175682368682205
# Negative Log-Likelihood: -1480.1555618210296
# The det_R in 0 0.1347040261499424
# The det_R in 1 0.08175682368682205
# Negative Log-Likelihood: -1480.1555618301554
# The det_R in 0 0.13470404099244965
# The det_R in 1 0.08175682368682205
# Negative Log-Likelihood: -1480.1555618221016
# The det_R in 0 0.13470403254699104
# The det_R in 1 0.08175682368682205
# Negative Log-Likelihood: -1480.1555618299521
# The det_R in 0 0.1347040365327714
# The det_R in 1 0.08175681310733315
# Negative Log-Likelihood: -1480.155562547318
# The det_R in 0 0.1347040365327714
# The det_R in 1 0.08175682383761969
# Negative Log-Likelihood: -1480.1555621514963
# The det_R in 0 0.1347040365327714
# The det_R in 1 0.08175681831739312
# Negative Log-Likelihood: -1480.1555618870261
# The det_R in 0 0.1347040365327714
# The det_R in 1 0.08175682373757487
# Negative Log-Likelihood: -1480.1555615535044
# The det_R in 0 0.1347040365327714
# The det_R in 1 0.081756826418334
# Negative Log-Likelihood: -1480.1555622083715
# The det_R in 0 0.1347040365327714
# The det_R in 1 0.0817568236420401
# Negative Log-Likelihood: -1480.1555618170125
# The det_R in 0 0.13991863879607763
# The det_R in 1 0.07543644843053252
# Negative Log-Likelihood: -1481.0485404463525
# The det_R in 0 0.13991863879607763
# The det_R in 1 0.07543644843053252
# Negative Log-Likelihood: -1481.0485399099239
# The det_R in 0 0.13991863879607763
# The det_R in 1 0.07543644843053252
# Negative Log-Likelihood: -1481.048538536449
# The det_R in 0 0.13991864884722116
# The det_R in 1 0.07543644843053252
# Negative Log-Likelihood: -1481.0485404399421
# The det_R in 0 0.13991862697109203
# The det_R in 1 0.07543644843053252
# Negative Log-Likelihood: -1481.0485404504052
# The det_R in 0 0.13991864379307237
# The det_R in 1 0.07543644843053252
# Negative Log-Likelihood: -1481.0485404408962
# The det_R in 0 0.13991862845010114
# The det_R in 1 0.07543644843053252
# Negative Log-Likelihood: -1481.0485404494761
# The det_R in 0 0.13991864321072753
# The det_R in 1 0.07543644843053252
# Negative Log-Likelihood: -1481.0485404419742
# The det_R in 0 0.13991863489265483
# The det_R in 1 0.07543644843053252
# Negative Log-Likelihood: -1481.048540449392
# The det_R in 0 0.13991863879607763
# The det_R in 1 0.07543643783540435
# Negative Log-Likelihood: -1481.0485401906103
# The det_R in 0 0.13991863879607763
# The det_R in 1 0.07543644850931776
# Negative Log-Likelihood: -1481.0485406430894
# The det_R in 0 0.13991863879607763
# The det_R in 1 0.07543644336685179
# Negative Log-Likelihood: -1481.048540362427
# The det_R in 0 0.13991863879607763
# The det_R in 1 0.07543644852848293
# Negative Log-Likelihood: -1481.0485402750455
# The det_R in 0 0.13991863879607763
# The det_R in 1 0.07543645105251974
# Negative Log-Likelihood: -1481.04854094101
# The det_R in 0 0.13991863879607763
# The det_R in 1 0.07543644840209139
# Negative Log-Likelihood: -1481.048540466322
# The det_R in 0 0.1495054966778668
# The det_R in 1 0.078561176979348
# Negative Log-Likelihood: -1481.5105988289993
# The det_R in 0 0.1495054966778668
# The det_R in 1 0.078561176979348
# Negative Log-Likelihood: -1481.5105982684727
# The det_R in 0 0.1495054966778668
# The det_R in 1 0.078561176979348
# Negative Log-Likelihood: -1481.510596919049
# The det_R in 0 0.14950550660570983
# The det_R in 1 0.078561176979348
# Negative Log-Likelihood: -1481.510598822797
# The det_R in 0 0.14950548491299503
# The det_R in 1 0.078561176979348
# Negative Log-Likelihood: -1481.5105988329974
# The det_R in 0 0.14950550158388032
# The det_R in 1 0.078561176979348
# Negative Log-Likelihood: -1481.510598823597
# The det_R in 0 0.14950548640003003
# The det_R in 1 0.078561176979348
# Negative Log-Likelihood: -1481.5105988319497
# The det_R in 0 0.14950550100957893
# The det_R in 1 0.078561176979348
# Negative Log-Likelihood: -1481.5105988248329
# The det_R in 0 0.14950549292654422
# The det_R in 1 0.078561176979348
# Negative Log-Likelihood: -1481.5105988321739
# The det_R in 0 0.1495054966778668
# The det_R in 1 0.07856118734195408
# Negative Log-Likelihood: -1481.5105982927412
# The det_R in 0 0.1495054966778668
# The det_R in 1 0.07856117703425074
# Negative Log-Likelihood: -1481.5105989514618
# The det_R in 0 0.1495054966778668
# The det_R in 1 0.07856117221558215
# Negative Log-Likelihood: -1481.5105993741365
# The det_R in 0 0.1495054966778668
# The det_R in 1 0.0785611771121997
# Negative Log-Likelihood: -1481.5105987298532
# The det_R in 0 0.1495054966778668
# The det_R in 1 0.07856117928458525
# Negative Log-Likelihood: -1481.5105988021332
# The det_R in 0 0.1495054966778668
# The det_R in 1 0.07856117694428172
# Negative Log-Likelihood: -1481.5105988438697
# The det_R in 0 0.15008545686206778
# The det_R in 1 0.0779234012524292
# Negative Log-Likelihood: -1481.6926624909097
# The det_R in 0 0.15008545686206778
# The det_R in 1 0.0779234012524292
# Negative Log-Likelihood: -1481.6926619269066
# The det_R in 0 0.15008545686206778
# The det_R in 1 0.0779234012524292
# Negative Log-Likelihood: -1481.6926605809558
# The det_R in 0 0.15008546678231344
# The det_R in 1 0.0779234012524292
# Negative Log-Likelihood: -1481.6926624845942
# The det_R in 0 0.15008544510070015
# The det_R in 1 0.0779234012524292
# Negative Log-Likelihood: -1481.692662495064
# The det_R in 0 0.15008546176232548
# The det_R in 1 0.0779234012524292
# Negative Log-Likelihood: -1481.6926624853927
# The det_R in 0 0.1500854465884018
# The det_R in 1 0.0779234012524292
# Negative Log-Likelihood: -1481.6926624939697
# The det_R in 0 0.15008546118848462
# The det_R in 1 0.0779234012524292
# Negative Log-Likelihood: -1481.6926624866674
# The det_R in 0 0.1500854531201845
# The det_R in 1 0.0779234012524292
# Negative Log-Likelihood: -1481.692662494244
# The det_R in 0 0.15008545686206778
# The det_R in 1 0.07792341152658389
# Negative Log-Likelihood: -1481.6926619549088
# The det_R in 0 0.15008545686206778
# The det_R in 1 0.07792340126797914
# Negative Log-Likelihood: -1481.6926625157623
# The det_R in 0 0.15008545686206778
# The det_R in 1 0.07792339649756146
# Negative Log-Likelihood: -1481.6926630004764
# The det_R in 0 0.15008545686206778
# The det_R in 1 0.07792340141755405
# Negative Log-Likelihood: -1481.6926624719906
# The det_R in 0 0.15008545686206778
# The det_R in 1 0.07792340353655929
# Negative Log-Likelihood: -1481.6926624615571
# The det_R in 0 0.15008545686206778
# The det_R in 1 0.07792340122608374
# Negative Log-Likelihood: -1481.6926625275196
# The det_R in 0 0.16115875885321518
# The det_R in 1 0.07283193305260557
# Negative Log-Likelihood: -1482.3638543510924
# The det_R in 0 0.16115875885321518
# The det_R in 1 0.07283193305260557
# Negative Log-Likelihood: -1482.3638537557194
# The det_R in 0 0.16115875885321518
# The det_R in 1 0.07283193305260557
# Negative Log-Likelihood: -1482.3638524411062
# The det_R in 0 0.16115876862895573
# The det_R in 1 0.07283193305260557
# Negative Log-Likelihood: -1482.3638543439333
# The det_R in 0 0.161158747160692
# ...
# The det_R in 0 0.011475226867813654
# The det_R in 1 0.07116136732932558
# Negative Log-Likelihood: -1482.6936931677474
# The det_R in 0 0.011475232877363161
# The det_R in 1 0.07116137665828805
# Negative Log-Likelihood: -1482.6936926834105
# The det_R in 0 0.011475232877363161
# The det_R in 1 0.07116136735202919
# Negative Log-Likelihood: -1482.6936931865935
# The det_R in 0 0.011475232877363161
# The det_R in 1 0.07116136264010954
# Negative Log-Likelihood: -1482.6936931618843
# The det_R in 0 0.011475232877363161
# The det_R in 1 0.07116136748368222
# Negative Log-Likelihood: -1482.6936931702749
# The det_R in 0 0.011475232877363161
# The det_R in 1 0.07116136940001919
# Negative Log-Likelihood: -1482.6936931467922
# The det_R in 0 0.011475232877363161
# The det_R in 1 0.07116136728249169
# Negative Log-Likelihood: -1482.6936931733103
# The det_R in 0 0.003526722218635046
# The det_R in 1 0.07144732657004108
# Negative Log-Likelihood: -1482.6942315192764
# The det_R in 0 0.003526722218635046
# The det_R in 1 0.07144732657004108
# Negative Log-Likelihood: -1482.6942311642424
# The det_R in 0 0.003526722218635046
# The det_R in 1 0.07144732657004108
# Negative Log-Likelihood: -1482.6942296105556
# The det_R in 0 0.003526734533954766
# The det_R in 1 0.07144732657004108
# Negative Log-Likelihood: -1482.694231519331
# The det_R in 0 0.003526711693607707
# The det_R in 1 0.07144732657004108
# Negative Log-Likelihood: -1482.6942315167485
# The det_R in 0 0.0035267298471187
# The det_R in 1 0.07144732657004108
# Negative Log-Likelihood: -1482.694231535544
# The det_R in 0 0.0035267123262531968
# The det_R in 1 0.07144732657004108
# Negative Log-Likelihood: -1482.6942315242927
# The det_R in 0 0.003526729389084276
# The det_R in 1 0.07144732657004108
# Negative Log-Likelihood: -1482.6942315294218
# The det_R in 0 0.003526716124919618
# The det_R in 1 0.07144732657004108
# Negative Log-Likelihood: -1482.6942315106057
# The det_R in 0 0.003526722218635046
# The det_R in 1 0.07144733600347684
# Negative Log-Likelihood: -1482.6942311020107
# The det_R in 0 0.003526722218635046
# The det_R in 1 0.0714473265840229
# Negative Log-Likelihood: -1482.6942315091508
# The det_R in 0 0.003526722218635046
# The det_R in 1 0.07144732184878907
# Negative Log-Likelihood: -1482.6942315000824
# The det_R in 0 0.003526722218635046
# The det_R in 1 0.0714473267297938
# Negative Log-Likelihood: -1482.6942315289452
# The det_R in 0 0.003526722218635046
# The det_R in 1 0.07144732868793635
# Negative Log-Likelihood: -1482.6942315404808
# The det_R in 0 0.003526722218635046
# The det_R in 1 0.07144732652682623
# Negative Log-Likelihood: -1482.694231525959
# The det_R in 0 0.004604392151242889
# The det_R in 1 0.07200336625401317
# Negative Log-Likelihood: -1482.7041389795613
# The det_R in 0 0.004604392151242889
# The det_R in 1 0.07200336625401317
# Negative Log-Likelihood: -1482.7041386361102
# The det_R in 0 0.004604392151242889
# The det_R in 1 0.07200336625401317
# Negative Log-Likelihood: -1482.704137070781
# The det_R in 0 0.004604404450508325
# The det_R in 1 0.07200336625401317
# Negative Log-Likelihood: -1482.7041389402239
# The det_R in 0 0.004604381657552872
# The det_R in 1 0.07200336625401317
# Negative Log-Likelihood: -1482.704139010761
# The det_R in 0 0.004604399547622623
# The det_R in 1 0.07200336625401317
# Negative Log-Likelihood: -1482.7041389680755
# The det_R in 0 0.0046043822371034816
# The det_R in 1 0.07200336625401317
# Negative Log-Likelihood: -1482.7041390145641
# The det_R in 0 0.004604399139576671
# The det_R in 1 0.07200336625401317
# Negative Log-Likelihood: -1482.7041389650194
# The det_R in 0 0.004604386234275543
# The det_R in 1 0.07200336625401317
# Negative Log-Likelihood: -1482.7041389919084
# The det_R in 0 0.004604392151242889
# The det_R in 1 0.07200337565579491
# Negative Log-Likelihood: -1482.7041384326103
# The det_R in 0 0.004604392151242889
# The det_R in 1 0.07200336628633117
# Negative Log-Likelihood: -1482.7041390156257
# The det_R in 0 0.004604392151242889
# The det_R in 1 0.07200336157374632
# Negative Log-Likelihood: -1482.7041390655709
# The det_R in 0 0.004604392151242889
# The det_R in 1 0.07200336640091444
# Negative Log-Likelihood: -1482.7041389527676
# The det_R in 0 0.004604392151242889
# The det_R in 1 0.07200336832456362
# Negative Log-Likelihood: -1482.7041389168214
# The det_R in 0 0.004604392151242889
# The det_R in 1 0.07200336620143324
# Negative Log-Likelihood: -1482.7041389626484
# The det_R in 0 -0.00036738305776673187
# The det_R in 1 0.0719372734310698
# Negative Log-Likelihood: nan
# The det_R in 0 -0.00036738305776673187
# The det_R in 1 0.0719372734310698
# Negative Log-Likelihood: nan
# The det_R in 0 -0.00036738305776673187
# The det_R in 1 0.0719372734310698
# Negative Log-Likelihood: nan
# The det_R in 0 -0.0003673706769754398
# The det_R in 1 0.0719372734310698
# Negative Log-Likelihood: nan
# The det_R in 0 -0.00036739318136687316
# The det_R in 1 0.0719372734310698
# Negative Log-Likelihood: nan
# The det_R in 0 -0.0003673758129426125
# The det_R in 1 0.0719372734310698
# Negative Log-Likelihood: nan
# The det_R in 0 -0.0003673927635157818
# The det_R in 1 0.0719372734310698
# Negative Log-Likelihood: nan
# The det_R in 0 -0.00036737611196014546
# The det_R in 1 0.0719372734310698
# Negative Log-Likelihood: nan
# The det_R in 0 -0.00036738874101351835
# The det_R in 1 0.0719372734310698
# Negative Log-Likelihood: nan
# The det_R in 0 -0.00036738305776673187
# The det_R in 1 0.07193728282662974
# Negative Log-Likelihood: nan
# The det_R in 0 -0.00036738305776673187
# The det_R in 1 0.07193727347086933
# Negative Log-Likelihood: nan
# The det_R in 0 -0.00036738305776673187
# The det_R in 1 0.07193726875047209
# Negative Log-Likelihood: nan
# The det_R in 0 -0.00036738305776673187
# The det_R in 1 0.07193727357410047
# Negative Log-Likelihood: nan
# The det_R in 0 -0.00036738305776673187
# The det_R in 1 0.07193727550157326
# Negative Log-Likelihood: nan
# The det_R in 0 -0.00036738305776673187
# The det_R in 1 0.07193727337586928
# Negative Log-Likelihood: nan
# The det_R in 0 -0.031816020131215116
# The det_R in 1 0.07166737911712591
# Negative Log-Likelihood: nan
# The det_R in 0 -0.031816020131215116
# The det_R in 1 0.07166737911712591
# Negative Log-Likelihood: nan
# The det_R in 0 -0.031816020131215116
# The det_R in 1 0.07166737911712591
# Negative Log-Likelihood: nan
# The det_R in 0 -0.03181600765343858
# The det_R in 1 0.07166737911712591
# Negative Log-Likelihood: nan
# The det_R in 0 -0.031816028682682185
# The det_R in 1 0.07166737911712591
# Negative Log-Likelihood: nan
# The det_R in 0 -0.03181601343964079
# The det_R in 1 0.07166737911712591
# Negative Log-Likelihood: nan
# The det_R in 0 -0.03181602869860912
# The det_R in 1 0.07166737911712591
# Negative Log-Likelihood: nan
# The det_R in 0 -0.03181601340388
# The det_R in 1 0.07166737911712591
# Negative Log-Likelihood: nan
# The det_R in 0 -0.03181602512934575
# The det_R in 1 0.07166737911712591
# Negative Log-Likelihood: nan
# The det_R in 0 -0.031816020131215116
# The det_R in 1 0.07166738848745934
# Negative Log-Likelihood: nan
# The det_R in 0 -0.031816020131215116
# The det_R in 1 0.0716673791868346
# Negative Log-Likelihood: nan
# The det_R in 0 -0.031816020131215116
# The det_R in 1 0.07166737443530305
# Negative Log-Likelihood: nan
# The det_R in 0 -0.031816020131215116
# The det_R in 1 0.07166737924468586
# Negative Log-Likelihood: nan
# The det_R in 0 -0.031816020131215116
# The det_R in 1 0.07166738118741066
# Negative Log-Likelihood: nan
# The det_R in 0 -0.031816020131215116
# The det_R in 1 0.07166737905142234
# Negative Log-Likelihood: nan
# The det_R in 0 -0.17525913621243874
# The det_R in 1 0.07049983181490213
# Negative Log-Likelihood: -1294.020124709692
# The det_R in 0 -0.17525913621243874
# The det_R in 1 0.07049983181490213
# Negative Log-Likelihood: -1294.020117134326
# The det_R in 0 -0.17525913621243874
# The det_R in 1 0.07049983181490213
# Negative Log-Likelihood: -1294.020166258638
# The det_R in 0 -0.17525912889491516
# The det_R in 1 0.07049983181490213
# Negative Log-Likelihood: -1294.0201176633097
# The det_R in 0 -0.17525913667105952
# The det_R in 1 0.07049983181490213
# Negative Log-Likelihood: -1294.0201274595438
# The det_R in 0 -0.17525913098737406
# The det_R in 1 0.07049983181490213
# Negative Log-Likelihood: -1294.020122005828
# The det_R in 0 -0.17525913547808913
# The det_R in 1 0.07049983181490213
# Negative Log-Likelihood: -1294.020128040706
# The det_R in 0 -0.175259129985962
# The det_R in 1 0.07049983181490213
# Negative Log-Likelihood: -1294.020122110389
# The det_R in 0 -0.17525914441833448
# The det_R in 1 0.07049983181490213
# Negative Log-Likelihood: -1294.0201236358553
# The det_R in 0 -0.17525913621243874
# The det_R in 1 0.07049984107893359
# Negative Log-Likelihood: -1294.0201238623004
# The det_R in 0 -0.17525913621243874
# The det_R in 1 0.07049983200398205
# Negative Log-Likelihood: -1294.020125252353
# The det_R in 0 -0.17525913621243874
# The det_R in 1 0.07049982712975564
# Negative Log-Likelihood: -1294.020124938608
# The det_R in 0 -0.17525913621243874
# The det_R in 1 0.07049983188077236
# Negative Log-Likelihood: -1294.020124498006
# The det_R in 0 -0.17525913621243874
# The det_R in 1 0.07049983388382675
# Negative Log-Likelihood: -1294.0201245146918
# The det_R in 0 -0.17525913621243874
# The det_R in 1 0.07049983170685936
# Negative Log-Likelihood: -1294.02012454215
# The det_R in 0 -0.17474196303373338
# The det_R in 1 0.07045720986993395
# Negative Log-Likelihood: -1303.3762618066958
# The det_R in 0 -0.17474196303373338
# The det_R in 1 0.07045720986993395
# Negative Log-Likelihood: -1303.3762546624293
# The det_R in 0 -0.17474196303373338
# The det_R in 1 0.07045720986993395
# Negative Log-Likelihood: -1303.3763008631554
# The det_R in 0 -0.17474195610377438
# The det_R in 1 0.07045720986993395
# Negative Log-Likelihood: -1303.376255702681
# The det_R in 0 -0.17474196315351678
# The det_R in 1 0.07045720986993395
# Negative Log-Likelihood: -1303.3762634924885
# The det_R in 0 -0.17474195784065666
# The det_R in 1 0.07045720986993395
# Negative Log-Likelihood: -1303.3762589214257
# The det_R in 0 -0.17474196184818214
# The det_R in 1 0.07045720986993395
# Negative Log-Likelihood: -1303.376263937223
# The det_R in 0 -0.1747419567819421
# The det_R in 1 0.07045720986993395
# Negative Log-Likelihood: -1303.3762590075978
# The det_R in 0 -0.1747419715733999
# The det_R in 1 0.07045720986993395
# Negative Log-Likelihood: -1303.3762607200197
# The det_R in 0 -0.17474196303373338
# The det_R in 1 0.0704572191301588
# Negative Log-Likelihood: -1303.376260951361
# The det_R in 0 -0.17474196303373338
# The det_R in 1 0.07045721006310934
# Negative Log-Likelihood: -1303.3762623691664
# The det_R in 0 -0.17474196303373338
# The det_R in 1 0.07045720518471804
# Negative Log-Likelihood: -1303.3762620946422
# The det_R in 0 -0.17474196303373338
# The det_R in 1 0.07045720993368931
# Negative Log-Likelihood: -1303.3762615549513
# The det_R in 0 -0.17474196303373338
# The det_R in 1 0.07045721193879807
# Negative Log-Likelihood: -1303.3762615854675
# The det_R in 0 -0.17474196303373338
# The det_R in 1 0.07045720976042662
# Negative Log-Likelihood: -1303.3762615981777
# The det_R in 0 -11.6603
# The det_R in 1 -11.6603
# Negative Log-Likelihood: 235.3055478081701
# The det_R in 0 -11.6603
# The det_R in 1 -11.6603
# Negative Log-Likelihood: 235.3055454023514
# The det_R in 0 -11.6603
# The det_R in 1 -11.6603
# Negative Log-Likelihood: 235.30537347843375
# The det_R in 0 -11.660299935020003
# The det_R in 1 -11.6603
# Negative Log-Likelihood: 235.30554807834028
# The det_R in 0 -11.660299935020003
# The det_R in 1 -11.6603
# Negative Log-Likelihood: 235.30554781391442
# The det_R in 0 -11.660299935020003
# The det_R in 1 -11.6603
# Negative Log-Likelihood: 235.3055480486747
# The det_R in 0 -11.660299935020003
# The det_R in 1 -11.6603
# Negative Log-Likelihood: 235.30554789579608
# The det_R in 0 -11.660299935020003
# The det_R in 1 -11.6603
# Negative Log-Likelihood: 235.3055479256464
# The det_R in 0 -11.660299935020003
# The det_R in 1 -11.6603
# Negative Log-Likelihood: 235.30554755465607
# The det_R in 0 -11.6603
# The det_R in 1 -11.660299935020003
# Negative Log-Likelihood: 235.30554765806448
# The det_R in 0 -11.6603
# The det_R in 1 -11.660299935020003
# Negative Log-Likelihood: 235.30554754303148
# The det_R in 0 -11.6603
# The det_R in 1 -11.660299935020003
# Negative Log-Likelihood: 235.30554805519617
# The det_R in 0 -11.6603
# The det_R in 1 -11.660299935020003
# Negative Log-Likelihood: 235.30554842510892
# The det_R in 0 -11.6603
# The det_R in 1 -11.660299935020003
# Negative Log-Likelihood: 235.3055472589929
# The det_R in 0 -11.6603
# The det_R in 1 -11.660299935020003
# Negative Log-Likelihood: 235.30554850760774
# The det_R in 0 -0.0024993708157932735
# The det_R in 1 0.07105279178663587
# Negative Log-Likelihood: nan
# The det_R in 0 -0.0024993708157932735
# The det_R in 1 0.07105279178663587
# Negative Log-Likelihood: nan
# The det_R in 0 -0.0024993708157932735
# The det_R in 1 0.07105279178663587
# Negative Log-Likelihood: nan
# The det_R in 0 -0.0024993584292220834
# The det_R in 1 0.07105279178663587
# Negative Log-Likelihood: nan
# The det_R in 0 -0.0024993813680335084
# The det_R in 1 0.07105279178663587
# Negative Log-Likelihood: nan
# The det_R in 0 -0.002499363348437953
# The det_R in 1 0.07105279178663587
# Negative Log-Likelihood: nan
# The det_R in 0 -0.0024993807900684215
# The det_R in 1 0.07105279178663587
# Negative Log-Likelihood: nan
# The det_R in 0 -0.002499363757680479
# The det_R in 1 0.07105279178663587
# Negative Log-Likelihood: nan
# The det_R in 0 -0.002499376853199245
# The det_R in 1 0.07105279178663587
# Negative Log-Likelihood: nan
# The det_R in 0 -0.0024993708157932735
# The det_R in 1 0.0710528012412491
# Negative Log-Likelihood: nan
# The det_R in 0 -0.0024993708157932735
# The det_R in 1 0.07105279175700542
# Negative Log-Likelihood: nan
# The det_R in 0 -0.0024993708157932735
# The det_R in 1 0.0710527870387589
# Negative Log-Likelihood: nan
# The det_R in 0 -0.0024993708157932735
# The det_R in 1 0.07105279197569929
# Negative Log-Likelihood: nan
# The det_R in 0 -0.0024993708157932735
# The det_R in 1 0.07105279393538262
# Negative Log-Likelihood: nan
# The det_R in 0 -0.0024993708157932735
# The det_R in 1 0.07105279175941023
# Negative Log-Likelihood: nan
# The det_R in 0 -3.344367315143804
# The det_R in 1 -2.277767810977714
# Negative Log-Likelihood: 272.021069370869
# The det_R in 0 -3.344367315143804
# The det_R in 1 -2.277767810977714
# Negative Log-Likelihood: 272.0210678677116
# The det_R in 0 -3.344367315143804
# The det_R in 1 -2.277767810977714
# Negative Log-Likelihood: 272.02089386064097
# The det_R in 0 -3.3443672798621096
# The det_R in 1 -2.277767810977714
# Negative Log-Likelihood: 272.0210701573809
# The det_R in 0 -3.344367344478988
# The det_R in 1 -2.277767810977714
# Negative Log-Likelihood: 272.02106830264745
# The det_R in 0 -3.344367286691378
# The det_R in 1 -2.277767810977714
# Negative Log-Likelihood: 272.02106986467044
# The det_R in 0 -3.3443673443098514
# The det_R in 1 -2.277767810977714
# Negative Log-Likelihood: 272.0210682744517
# The det_R in 0 -3.3443672870450465
# The det_R in 1 -2.277767810977714
# Negative Log-Likelihood: 272.0210697298136
# The det_R in 0 -3.3443673486478445
# The det_R in 1 -2.277767810977714
# Negative Log-Likelihood: 272.0210698660911
# The det_R in 0 -3.344367315143804
# The det_R in 1 -2.2777677855712724
# Negative Log-Likelihood: 272.0210663300593
# The det_R in 0 -3.344367315143804
# The det_R in 1 -2.2777678384826197
# Negative Log-Likelihood: 272.0210688013002
# The det_R in 0 -3.344367315143804
# The det_R in 1 -2.277767835101348
# Negative Log-Likelihood: 272.0210705593874
# The det_R in 0 -3.344367315143804
# The det_R in 1 -2.2777677907368474
# Negative Log-Likelihood: 272.0210700682335
# The det_R in 0 -3.344367315143804
# The det_R in 1 -2.277767781814064
# Negative Log-Likelihood: 272.0210684906246
# The det_R in 0 -3.344367315143804
# The det_R in 1 -2.277767792116821
# Negative Log-Likelihood: 272.0210702967354
#   message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   success: True
#    status: 0
#       fun: 272.021069370869
#         x: [ 9.900e-01  9.900e-01 ... -1.678e-01 -4.699e-01]
#       nit: 47
#       jac: [ 1.503e+02  1.755e+04 ... -8.802e+01  9.259e+01]
#      nfev: 1110
#      njev: 74
#  hess_inv: <14x14 LbfgsInvHessProduct with dtype=float64>

# %%
from importlib import reload
reload(Filter)
from Filter import Base
model.plot_heatmaps()
# Out:
# Verify that the First Correlation Matrix is Valid!
# [-0.82985571  1.89978289  1.62316832  1.3069045 ]
# (False, 'The matrix is not positive semi-definite.')
# Verify that the Second Correlation Matrix is Valid!
# [-0.67329871  2.17106982  1.33520118  1.16702771]
# (False, 'The matrix is not positive semi-definite.')

# %%
model.smoothing_step()

# %%
from importlib import reload
reload(Filter)
from Filter import Base
model.plot_my_probabilities()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 4
#       2 reload(Filter)
#       3 from Filter import Base
# ----> 4 model.plot_my_probabilities()
#
# File ~/code/jupyter/Thesis/Filter.py:640, in Base.plot_my_probabilities(self)
#     638 ax[1].fill_between(x, 0, 1 - self.filtered_probabilities[0, :], color='darkblue', alpha=0.7)
#     639 ax[1].fill_between(x, 1 - self.filtered_probabilities[0, :], 1, color='darkorange', alpha=0.0)
# --> 640 ax[2].fill_between(x, 0, 1 - self.smoothed_probabilities[0, :], color='darkblue', alpha=0.7)
#     641 ax[2].fill_between(x, 1 - self.smoothed_probabilities[0, :], 1, color='darkorange', alpha=0.0)
#     643 # Setting titles and limits
#
# AttributeError: 'Base' object has no attribute 'smoothed_probabilities'

# %%
model.transition_matrix
